# %% [markdown]
# # CMSE202-Project1

# %%
import pandas as pd
from sodapy import Socrata
import matplotlib.pyplot as plt
# %matplotlib inline

MyAppToken = 'rEPOXGSegb5AUSutACzeimRkD'
client = Socrata("data.cityofchicago.org", MyAppToken)

results = client.get("ijzp-q8t2", limit=100)

df = pd.DataFrame.from_records(results)

# %%
data = df.drop(columns=[':@computed_region_43wa_7qmu', ':@computed_region_6mkv_f3dw',
       ':@computed_region_awaf_s7ux', ':@computed_region_bdys_3d7i',
       ':@computed_region_d3ds_rm58', ':@computed_region_d9mm_jgwp',
       ':@computed_region_rpca_8um6', ':@computed_region_vrxf_vc4k'])

data.head()
# Out:
#    arrest  beat                   block case_number community_area  \
# 0   False  2424  074XX N WINCHESTER AVE    JD198885              1
# 1   False  0323      071XX S RHODES AVE    JD198637             69
# 2    True  0411         011XX E 81ST ST    JD198648             45
# 3   False  1234         022XX W 21ST ST    JD198629             31
# 4   False  0111        001XX N STATE ST    JD198626             32
#
#                       date                              description district  \
# 0  2020-03-30T23:55:00.000      FINANCIAL IDENTITY THEFT OVER $ 300      024
# 1  2020-03-30T23:45:00.000                          ARMED - HANDGUN      003
# 2  2020-03-30T23:33:00.000                   UNLAWFUL USE - HANDGUN      004
# 3  2020-03-30T23:32:00.000                   UNLAWFUL USE - HANDGUN      012
# 4  2020-03-30T23:30:00.000  AGGRAVATED - KNIFE / CUTTING INSTRUMENT      001
#
#    domestic fbi_code  ...      latitude  \
# 0     False       11  ...  42.017111558
# ...
